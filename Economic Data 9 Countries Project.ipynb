# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('Economic Data - 9 Countries (1980-2020).csv')
df
# Out:
#     stock index                   country    year index price  log_indexprice  \
# 0        NASDAQ  United States of America  1980.0      168.61            2.23
# 1        NASDAQ  United States of America  1981.0      203.15            2.31
# 2        NASDAQ  United States of America  1982.0      188.98            2.28
# 3        NASDAQ  United States of America  1983.0      285.43            2.46
# 4        NASDAQ  United States of America  1984.0      248.89            2.40
# ..          ...                       ...     ...         ...             ...
# 364      IEX 35                     Spain  2016.0     9352.10            3.97
# 365      IEX 35                     Spain  2017.0    10043.90            4.00
# 366      IEX 35                     Spain  2018.0     8539.90            3.93
# 367      IEX 35                     Spain  2019.0     9549.20            3.98
# 368      IEX 35                     Spain  2020.0     8073.70            3.91
#
# ...

# %% [raw]
# Reading top 5 rows of the dataset

# %%
df.head()
# Out:
#   stock index                   country    year index price  log_indexprice  \
# 0      NASDAQ  United States of America  1980.0      168.61            2.23
# 1      NASDAQ  United States of America  1981.0      203.15            2.31
# 2      NASDAQ  United States of America  1982.0      188.98            2.28
# 3      NASDAQ  United States of America  1983.0      285.43            2.46
# 4      NASDAQ  United States of America  1984.0      248.89            2.40
#
#   inflationrate  oil prices exchange_rate  gdppercent percapitaincome  \
# 0          0.14       21.59             .        0.09        12575.00
# 1          0.10       31.77             .        0.12        13976.00
# 2          0.06       28.52             .        0.04        14434.00
# 3          0.03       26.19             .        0.09        15544.00
# 4          0.04       25.88             .        0.11        17121.00
#
#   unemploymentrate manufacturingoutput tradebalance  USTreasury
# ...

# %% [raw]
# # Checking columns information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stock index          369 non-null    object
#  1   country              369 non-null    object
#  2   year                 369 non-null    float64
#  3   index price          369 non-null    object
#  4   log_indexprice       369 non-null    float64
#  5   inflationrate        369 non-null    object
#  6   oil prices           369 non-null    float64
#  7   exchange_rate        369 non-null    object
#  8   gdppercent           369 non-null    float64
#  9   percapitaincome      369 non-null    object
#  10  unemploymentrate     369 non-null    object
#  11  manufacturingoutput  369 non-null    object
#  12  tradebalance         369 non-null    object
#  13  USTreasury           369 non-null    float64
# dtypes: float64(5), object(9)
# memory usage: 40.5+ KB

# %% [raw]
# # Observation: Some discrepancies are present in data wrt to datatype of certain columns

# %% [raw]
# # Checking for any missing values

# %%
df.isnull().sum()
# Out:
# stock index            0
# country                0
# year                   0
# index price            0
# log_indexprice         0
# inflationrate          0
# oil prices             0
# exchange_rate          0
# gdppercent             0
# percapitaincome        0
# unemploymentrate       0
# manufacturingoutput    0
# tradebalance           0
# USTreasury             0
# dtype: int64

# %% [raw]
# # Observation : Presence of missing values is none.

# %% [markdown]
# # Correcting datatypes of columns

# %%
df.year = df.year.astype('int64')

# %%
df['index price'] = pd.to_numeric(df['index price'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stock index          369 non-null    object
#  1   country              369 non-null    object
#  2   year                 369 non-null    int64
#  3   index price          317 non-null    float64
#  4   log_indexprice       369 non-null    float64
#  5   inflationrate        369 non-null    object
#  6   oil prices           369 non-null    float64
#  7   exchange_rate        369 non-null    object
#  8   gdppercent           369 non-null    float64
#  9   percapitaincome      369 non-null    object
#  10  unemploymentrate     369 non-null    object
#  11  manufacturingoutput  369 non-null    object
#  12  tradebalance         369 non-null    object
#  13  USTreasury           369 non-null    float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 40.5+ KB

# %%
df['inflationrate'] = pd.to_numeric(df['inflationrate'], errors='coerce')

# %%
df['exchange_rate'].unique()
# Out:
# array(['.', '2.32', '2.02', '1.75', '1.52', '1.34', '1.30', '1.47',
#        '1.64', '1.78', '1.77', '1.50', '1.53', '1.58', '1.56', '1.66',
#        '1.62', '1.44', '1.63', '1.83', '1.82', '1.84', '2.00', '1.85',
#        '1.57', '1.55', '1.60', '1.59', '1.65', '1.36', '1.29', '1.28',
#        '7.89', '8.68', '9.48', '10.10', '11.35', '12.33', '12.60',
#        '12.95', '13.90', '16.21', '17.49', '22.71', '28.16', '31.29',
#        '31.39', '32.42', '35.51', '36.36', '41.36', '43.13', '45.00',
#        '47.22', '48.63', '46.59', '45.26', '44.00', '45.19', '41.18',
#        '43.39', '48.33', '45.65', '46.58', '53.37', '58.51', '61.00',
#        '64.11', '67.16', '65.07', '68.37', '70.38', '74.14', '226.58',
#        '220.45', '249.05', '237.45', '237.59', '238.47', '168.50',
#        '144.62', '128.14', '137.99', '144.82', '134.51', '126.75',
#        '111.23', '102.20', '94.11', '108.80', '121.09', '130.82',
#        '113.71', '107.82', '121.52', '125.27', '115.92', '108.16',
# ...

# %%
df['exchange_rate'] = pd.to_numeric(df['exchange_rate'], errors='coerce')

# %%
df['percapitaincome'] = pd.to_numeric(df['percapitaincome'], errors='coerce')

# %%
df['unemploymentrate'] = pd.to_numeric(df['unemploymentrate'], errors='coerce')

# %%
df['tradebalance'] = pd.to_numeric(df['tradebalance'], errors='coerce')

# %%
df['manufacturingoutput'] = pd.to_numeric(df['manufacturingoutput'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stock index          369 non-null    object
#  1   country              369 non-null    object
#  2   year                 369 non-null    int64
#  3   index price          317 non-null    float64
#  4   log_indexprice       369 non-null    float64
#  5   inflationrate        360 non-null    float64
#  6   oil prices           369 non-null    float64
#  7   exchange_rate        326 non-null    float64
#  8   gdppercent           369 non-null    float64
#  9   percapitaincome      368 non-null    float64
#  10  unemploymentrate     348 non-null    float64
#  11  manufacturingoutput  278 non-null    float64
#  12  tradebalance         366 non-null    float64
#  13  USTreasury           369 non-null    float64
# dtypes: float64(11), int64(1), object(2)
# ...

# %% [markdown]
# #### FInd the number of unique countries

# %%
df['country'].unique()
# Out:
# array(['United States of America', 'United Kingdom', 'India', 'Japan',
#        'Hong Kong', 'China', 'Germany', 'France', 'Spain'], dtype=object)

# %%
print("Number of countries in this dataset is: ", len(df['country'].unique()))
# Out:
# Number of countries in this dataset is:  9

# %%
df.head()
# Out:
#   stock index                   country  year  index price  log_indexprice  \
# 0      NASDAQ  United States of America  1980       168.61            2.23
# 1      NASDAQ  United States of America  1981       203.15            2.31
# 2      NASDAQ  United States of America  1982       188.98            2.28
# 3      NASDAQ  United States of America  1983       285.43            2.46
# 4      NASDAQ  United States of America  1984       248.89            2.40
#
#    inflationrate  oil prices  exchange_rate  gdppercent  percapitaincome  \
# 0           0.14       21.59            NaN        0.09          12575.0
# 1           0.10       31.77            NaN        0.12          13976.0
# 2           0.06       28.52            NaN        0.04          14434.0
# 3           0.03       26.19            NaN        0.09          15544.0
# 4           0.04       25.88            NaN        0.11          17121.0
#
#    unemploymentrate  manufacturingoutput  tradebalance  USTreasury
# ...

# %% [markdown]
# ####Find Years to be analysed

# %%
df['year'].unique()
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %% [markdown]
# #### Let's look at the inflation rate data of India from 1980 - 2020

# %%
df_india = df[df['country'] == 'India']
df_india.head()
# Out:
#    stock index country  year  index price  log_indexprice  inflationrate  \
# 82    Nifty 50   India  1980          NaN            3.02           0.11
# 83    Nifty 50   India  1981          NaN            3.02           0.13
# 84    Nifty 50   India  1982          NaN            3.02           0.08
# 85    Nifty 50   India  1983          NaN            3.02           0.12
# 86    Nifty 50   India  1984          NaN            3.02           0.08
#
#     oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 82       21.59           7.89        0.07            267.0             0.028
# 83       31.77           8.68        0.06            270.0             0.028
# 84       28.52           9.48        0.03            274.0             0.028
# 85       26.19          10.10        0.07            291.0             0.028
# 86       25.88          11.35        0.04            277.0             0.028
#
#     manufacturingoutput  tradebalance  USTreasury
# ...

# %% [markdown]
# #### Plot the inflation rate of India

# %%
plt.figure(figsize = (15,6))
sns.set_style("whitegrid")
plt.title("India Inflation Rate 1980-2020", fontsize=20, color = 'green')
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Inflation rate", fontsize = 15)
sns.lineplot(x = 'year', y = 'inflationrate', data = df_india , color = 'green')
plt.show()

# %% [markdown]
# ##### PLot Per Capita Income of India 1980-2020 period

# %%
plt.figure(figsize = (15,6))
sns.set_style("whitegrid")
plt.title("India Per Capita Income 1980-2020", fontsize=20, color = 'green')
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Per Capita Income", fontsize = 15)
sns.lineplot(x = 'year', y = 'percapitaincome', data = df_india , color = 'green')
plt.show()

# %% [markdown]
# #### Plot Unemployment Rate in India from 1980-2020

# %%
plt.figure(figsize = (15,6))
plt.title("India Unemployment Rate 1980 - 2020", fontsize = 20, color = 'green')
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Unemployment Rate", fontsize = 15)
sns.lineplot(x = 'year', y = 'unemploymentrate', data = df_india)
plt.show()

# %% [markdown]
# #### PLot India's Manufacturing Output 1980 - 2020

# %%
plt.figure(figsize = (15,6))
plt.title("India Manufacturing Output 1980 - 2020", fontsize = 20, color = 'brown')
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Manufacturing Output", fontsize = 15)
sns.lineplot(x = 'year', y = 'manufacturingoutput', data = df_india, color = 'green')
plt.show()

# %% [markdown]
# #### Plot GDP Percentage of India 1980 - 2020

# %%
plt.figure(figsize = (15,6))
plt.title("India Gross Domestic Product Rate 1980 - 2020", fontsize = 20, color = 'brown')
sns.set_style("darkgrid")
plt.xlabel("Year", fontsize = 15)
plt.ylabel("Manufacturing Output", fontsize = 15)
sns.lineplot(x = 'year', y = 'gdppercent', data = df_india, color = 'green')
plt.show()

# %% [markdown]
# #### FInd in which year unemployment rate was highest for India in this period

# %%
df_india.head()
# Out:
#    stock index country  year  index price  log_indexprice  inflationrate  \
# 82    Nifty 50   India  1980          NaN            3.02           0.11
# 83    Nifty 50   India  1981          NaN            3.02           0.13
# 84    Nifty 50   India  1982          NaN            3.02           0.08
# 85    Nifty 50   India  1983          NaN            3.02           0.12
# 86    Nifty 50   India  1984          NaN            3.02           0.08
#
#     oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 82       21.59           7.89        0.07            267.0             0.028
# 83       31.77           8.68        0.06            270.0             0.028
# 84       28.52           9.48        0.03            274.0             0.028
# 85       26.19          10.10        0.07            291.0             0.028
# 86       25.88          11.35        0.04            277.0             0.028
#
#     manufacturingoutput  tradebalance  USTreasury
# ...

# %%
df_india['unemploymentrate'].max()
# Out:
# 0.0711

# %%
x = df_india[df_india['unemploymentrate'] == 0.0711]
x
# Out:
#     stock index country  year  index price  log_indexprice  inflationrate  \
# 121    Nifty 50   India  2019     41253.74            4.62           0.04
#
#      oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 121       59.88          70.38        0.04           2101.0            0.0711
#
#      manufacturingoutput  tradebalance  USTreasury
# 121               382.56        -72.57        0.02

# %% [markdown]
# So, India's unemployment rate was highest in 2019, during 1980-2020

# %% [markdown]
# #### Find the year in which Exchange rate was the highest?

# %%
exr_max = df_india[df_india['exchange_rate'] == df_india['exchange_rate'].max()]
exr_max
# Out:
#     stock index country  year  index price  log_indexprice  inflationrate  \
# 122    Nifty 50   India  2020     47751.33            4.68           0.07
#
#      oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 122       47.02          74.14       -0.08           1901.0            0.0618
#
#      manufacturingoutput  tradebalance  USTreasury
# 122               339.98         -8.31        0.01

# %% [raw]
# Exchange rate was highest i.e. 74.14 in the year 2020.

# %% [markdown]
# #### Find the year GDP reached at its peak value?

# %%
gdp_max = df_india[df_india['gdppercent'] == df_india['gdppercent'].max()]
gdp_max
# Out:
#    stock index country  year  index price  log_indexprice  inflationrate  \
# 90    Nifty 50   India  1988          NaN            3.02           0.09
#
#     oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 90       12.58           13.9         0.1            354.0             0.028
#
#     manufacturingoutput  tradebalance  USTreasury
# 90                47.76         -4.21        0.09

# %% [markdown]
# 1988 was the year, in which GDP reached at 10%! wow!

# %% [markdown]
# #### Now, we move our attention to Germany & perform a similar analysis

# %%
df_germany = df[df['country'] == 'Germany']
df_germany
# Out:
#     stock index  country  year  index price  log_indexprice  inflationrate  \
# 246      DAX 30  Germany  1980       480.90            2.68           0.05
# 247      DAX 30  Germany  1981       490.40            2.69           0.06
# 248      DAX 30  Germany  1982       552.80            2.74           0.05
# 249      DAX 30  Germany  1983       774.00            2.89           0.03
# 250      DAX 30  Germany  1984       820.90            2.91           0.02
# 251      DAX 30  Germany  1985      1366.20            3.14           0.02
# 252      DAX 30  Germany  1986      1432.30            3.16           0.00
# 253      DAX 30  Germany  1987      1000.00            3.00           0.00
# 254      DAX 30  Germany  1988      1327.87            3.12           0.01
# 255      DAX 30  Germany  1989      1790.37            3.25           0.03
# 256      DAX 30  Germany  1990      1398.20            3.15           0.03
# ...

# %%
df_germany.isnull().sum()
# Out:
# stock index             0
# country                 0
# year                    0
# index price             0
# log_indexprice          0
# inflationrate           0
# oil prices              0
# exchange_rate           0
# gdppercent              0
# percapitaincome         0
# unemploymentrate        0
# manufacturingoutput    11
# tradebalance            0
# USTreasury              0
# dtype: int64

# %% [markdown]
# #### So, we have some missing values in the column 'Manufacturing Output'. We've to address it.

# %%
df_germany['manufacturingoutput'].unique()
# Out:
# array([   nan, 237.43, 254.79, 225.8 , 234.55, 271.52, 256.13, 228.78,
#        233.65, 438.87, 400.23, 395.8 , 411.33, 496.31, 563.82, 571.36,
#        618.7 , 714.38, 750.91, 603.23, 669.57, 758.6 , 710.95, 743.97,
#        786.55, 683.2 , 716.94, 752.02, 795.96, 737.94, 678.29])

# %%
df_germany['manufacturingoutput'] = df_germany['manufacturingoutput'].fillna(df_germany['manufacturingoutput'].mean())
# Out:
# C:\Users\Kausiek\AppData\Local\Temp/ipykernel_9808/1441431799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_germany['manufacturingoutput'] = df_germany['manufacturingoutput'].fillna(df_germany['manufacturingoutput'].mean())

# %%
df_germany.isnull().sum()
# Out:
# stock index            0
# country                0
# year                   0
# index price            0
# log_indexprice         0
# inflationrate          0
# oil prices             0
# exchange_rate          0
# gdppercent             0
# percapitaincome        0
# unemploymentrate       0
# manufacturingoutput    0
# tradebalance           0
# USTreasury             0
# dtype: int64

# %% [markdown]
# #### Plot the inflation rate of Germany during 1980 - 2020

# %%
plt.figure(figsize = (15,6))
sns.set_style("whitegrid")
plt.title("Inflation Rate of Germany during 1980 - 2020", fontsize = 20, color = 'brown')
plt.xlabel("Year", fontsize = 15, color = 'green')
plt.ylabel("Yearly Inflation Rate", fontsize = 15, color = 'green')
sns.lineplot(x = 'year', y = 'inflationrate', data = df_germany, color = 'green')
plt.show()

# %% [markdown]
# #### Plot Per Capita Income if Germany

# %%
plt.figure(figsize = (15,6))
plt.title("Per Capita Income of Germany during 1980 - 2020", fontsize = 20, color = 'brown')
plt.xlabel("Year", fontsize = 15, color = 'green')
plt.ylabel("Per Capita Income", fontsize = 15, color = 'green')
sns.lineplot(x = 'year', y = 'percapitaincome', data = df_germany, color = 'green')
plt.show()

# %% [markdown]
# #### Plot Unemployment Rate of Germany

# %%
plt.figure(figsize = (15,6))
plt.title("Unemployment Rate of Germany during 1980 - 2020", fontsize = 20, color = 'brown')
plt.xlabel("Year", fontsize = 15, color = 'green')
plt.ylabel("Unemployment Rate", fontsize = 15, color = 'green')
sns.lineplot(x = 'year', y = 'unemploymentrate', data = df_germany, color = 'green')
plt.show()

# %% [markdown]
# #### Plot Manufacturing Output of Germany

# %%
plt.figure(figsize = (15,6))
plt.title("Manufacturing Output of Germany during 1980 - 2020", fontsize = 20, color = 'brown')
plt.xlabel("Year", fontsize = 15, color = 'green')
plt.ylabel("Manufacturing Output", fontsize = 15, color = 'green')
sns.lineplot(x = 'year', y = 'manufacturingoutput', data = df_germany, color = 'green')
plt.show()

# %% [markdown]
# #### Plot Germany's GDP during 1980-2020

# %%
plt.figure(figsize = (15,6))
plt.title("Gross Domestic Product of Germany during 1980 - 2020", fontsize = 20, color = 'brown')
plt.xlabel("Year", fontsize = 15, color = 'green')
plt.ylabel("Gross Domestic Product", fontsize = 15, color = 'green')
sns.lineplot(x = 'year', y = 'gdppercent', data = df_germany, color = 'green')
plt.show()

# %% [markdown]
# #### FInd in which year unemployment rate was highest for India in this period?

# %%
ue_max = df_germany[df_germany['unemploymentrate'] == df_germany['unemploymentrate'].max()]
ue_max
# Out:
#     stock index  country  year  index price  log_indexprice  inflationrate  \
# 271      DAX 30  Germany  2005      5408.25            3.73           0.02
#
#      oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 271       59.41           1.24        0.01          34520.0            0.1173
#
#      manufacturingoutput  tradebalance  USTreasury
# 271               571.36        148.05        0.04

# %% [markdown]
# Unemployment rate peaked in 2005 for Germany at 11.73%

# %% [markdown]
# #### Find the year in which Exchange rate was the highest?

# %%
er_max = df_germany[df_germany['exchange_rate'] == df_germany['exchange_rate'].max()]
er_max
# Out:
#     stock index  country  year  index price  log_indexprice  inflationrate  \
# 251      DAX 30  Germany  1985       1366.2            3.14           0.02
#
#      oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 251       24.09           2.94        0.02           4821.0            0.0818
#
#      manufacturingoutput  tradebalance  USTreasury
# 251              531.386         -7.63        0.11

# %% [markdown]
# IN 1985, the exchange rate was highest in Germany.

# %% [markdown]
# #### Find the year GDP reached at its peak value in Germany?

# %%
gdp_max = df_germany[df_germany['gdppercent'] == df_germany['gdppercent'].max()]
gdp_max
# Out:
#     stock index  country  year  index price  log_indexprice  inflationrate  \
# 256      DAX 30  Germany  1990       1398.2            3.15           0.03
# 257      DAX 30  Germany  1991       1578.0            3.20           0.04
#
#      oil prices  exchange_rate  gdppercent  percapitaincome  unemploymentrate  \
# 256       27.28           1.62        0.05          11404.0            0.0642
# 257       19.50           1.66        0.05          11942.0            0.0587
#
#      manufacturingoutput  tradebalance  USTreasury
# 256              531.386         -1.74        0.09
# 257              237.430         -4.66        0.08

# %% [markdown]
# So, in both 1990 & 1991, GDP Percent reached peak for Germany.

# %%
df.head()
# Out:
#   stock index                   country  year  index price  log_indexprice  \
# 0      NASDAQ  United States of America  1980       168.61            2.23
# 1      NASDAQ  United States of America  1981       203.15            2.31
# 2      NASDAQ  United States of America  1982       188.98            2.28
# 3      NASDAQ  United States of America  1983       285.43            2.46
# 4      NASDAQ  United States of America  1984       248.89            2.40
#
#    inflationrate  oil prices  exchange_rate  gdppercent  percapitaincome  \
# 0           0.14       21.59            NaN        0.09          12575.0
# 1           0.10       31.77            NaN        0.12          13976.0
# 2           0.06       28.52            NaN        0.04          14434.0
# 3           0.03       26.19            NaN        0.09          15544.0
# 4           0.04       25.88            NaN        0.11          17121.0
#
#    unemploymentrate  manufacturingoutput  tradebalance  USTreasury
# ...

# %% [markdown]
# #### FInd top five (5) countries in terms of Per Capita Income & Plot a bargraph on it

# %%
top_5_pci = df['percapitaincome'].groupby(df['country']).mean().sort_values(ascending=False).reset_index()[:5]
top_5_pci
# Out:
#                     country  percapitaincome
# 0  United States of America     36879.365854
# 1                     Japan     31789.825000
# 2            United Kingdom     29003.609756
# 3                   Germany     25506.195122
# 4                 Hong Kong     24943.634146

# %%
plt.figure(figsize = (8,6))
plt.title("Top Five (5) Countries wrt Per Capita Income", fontsize = 18, color = 'brown')
plt.xlabel("Country", fontsize = 14.5, color = 'green')
plt.ylabel("Per Capita Income", fontsize = 14.5, color = 'green')
plt.xticks(rotation = 60)
sns.barplot(x = 'country', y = 'percapitaincome', data = top_5_pci)
plt.show()

# %% [markdown]
# #### Rank Countries in increasing order of unemployment rate

# %%
df_urt = df['unemploymentrate'].groupby(df['country']).mean().sort_values().reset_index()
df_urt
# Out:
#                     country  unemploymentrate
# 0                     China          0.035500
# 1                     Japan          0.035661
# 2                 Hong Kong          0.040370
# 3                     India          0.049824
# 4            United Kingdom          0.059773
# 5  United States of America          0.062463
# 6                   Germany          0.080066
# 7                    France          0.098621
# 8                     Spain          0.166691

# %%
plt.figure(figsize = (10,5))
plt.title("Countries with increasing order of their Unemployment rate", fontsize = 18, color = 'brown')
plt.xlabel("Country", fontsize = 14.5, color = 'green')
plt.ylabel("Unemployment Rate", fontsize = 14.5, color = 'green')
plt.xticks(rotation = 60)
sns.barplot(x = 'country', y = 'unemploymentrate', data = df_urt)
plt.show()

# %% [markdown]
# #### Find top 5 countries that have faced high inflation rates during 1980 -2020

# %%
top_5_ir = df['inflationrate'].groupby(df['country']).mean().sort_values(ascending=False).reset_index()[:5]
top_5_ir
# Out:
#           country  inflationrate
# 0           India       0.077561
# 1           China       0.050000
# 2           Spain       0.046098
# 3       Hong Kong       0.040513
# 4  United Kingdom       0.036341

# %%
plt.figure(figsize = (7,4.6))
plt.title("Top Five (5) Countries with High Inflation Rate", fontsize = 18, color = 'brown')
plt.xlabel("Country", fontsize = 14.5, color = 'green')
plt.ylabel("Inflation Rate", fontsize = 14.5, color = 'green')
plt.xticks(rotation = 60)
sns.barplot(x = 'country', y = 'inflationrate', data = top_5_ir, palette="magma")
plt.show()

# %% [markdown]
# #### Arrange Countries in descending order wrt GDP Percentage

# %%
gdp_coun = df['gdppercent'].groupby(df['country']).mean().sort_values(ascending=True).reset_index()
gdp_coun
# Out:
#                     country  gdppercent
# 0                   Germany    0.015366
# 1                    France    0.015610
# 2                     Japan    0.017317
# 3            United Kingdom    0.018049
# 4                     Spain    0.019756
# 5  United States of America    0.037561
# 6                 Hong Kong    0.042927
# 7                     India    0.057805
# 8                     China    0.092439

# %%
plt.figure(figsize = (10,5))
plt.title("Countries with increasing order of their GDP growth", fontsize = 18, color = 'brown')
plt.xlabel("Country", fontsize = 14.5, color = 'green')
plt.ylabel("GDP Rate", fontsize = 14.5, color = 'green')
plt.xticks(rotation = 60)
sns.barplot(x = 'country', y = 'gdppercent', data = gdp_coun, palette="rocket")
plt.show()
